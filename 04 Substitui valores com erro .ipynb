# %%
import  pandas as pd
import plotly.graph_objects as go
import random

# %%
dados = pd.read_csv('dados/dados_primeira_infancia_300k_com_desvio.csv')

# %%
dados.head(1)
# Out:
#               nome  latitude  longitude  ID_FAMILIA_CADUNICO        LAT  \
# 0  Abadia de Goiás  -16.7573   -49.4412                 3961 -16.765013
#
#          LOG  CODG_FAMILIAR  STAT_CADASTRO DESC_STAT_CADASTRO  \
# 0 -49.427965     2468632346              3           Cadastro
#
#   INDI_CADASTRO_VALIDO  ...  QTDE_CRIANCAS_ATE_3ANOS QTDE_CRIANCAS_ATE_6ANOS  \
# 0                    S  ...                        0                       0
#
#   QTDE_MAIOR18_NAO_SABE_LER QTDE_ENTRE6E17_NAO_FREQ_ESCOLA  \
# 0                         0                              0
#
#    QTDE_PESSOA_INTERNACAO VALR_DESPESA_ALUGUEL INDI_FAMILIA_RECEBE_BPC  \
# 0                       0                  0.0                       S
#
#    INDI_RECEBE_AJUDA_DEFIC_TERC    DESVIO aproximação
# 0                             N  1.649214          ok
#
# [1 rows x 43 columns]

# %% [markdown]
# ### solução para gerar coordenada dinâmica

# %%
#num_randon = []
#for d, i in dados.iterrows():
#    if i['aproximação'] == 'Erro':
#        num_randon.append(random.uniform(-0.001, 0.0100))
#    else:
#        num_randon.append(0)

# %%
selecao = (dados['aproximação'] == 'Erro')
df1 = dados[selecao]

# %%
lat_radom = []
for d, i in df1.iterrows():
    lat_radom.append(random.uniform(-0.001, 0.0100))

# %%
lon_radom = []
for d, i in df1.iterrows():
    lon_radom.append(random.uniform(0.001, -0.0100))

# %%
df1['lat_corrigido'] = df1['latitude'] + lat_radom
df1['lon_corrigido'] = df1['longitude'] + lon_radom
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
selecao = (dados['aproximação'] == 'ok')
df2 = dados[selecao]

# %%
df2['lat_corrigido'] = dados['LAT']    #mantendo os dados corretos de lat e long
df2['lon_corrigido'] = dados['LOG']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
novo_dados = pd.concat([df1,df2], ignore_index=True)  #juntando os dados
novo_dados
# Out:
#                    nome  latitude  longitude  ID_FAMILIA_CADUNICO        LAT  \
# 0       Abadia de Goiás  -16.7573   -49.4412                 4154 -16.678533
# 1       Abadia de Goiás  -16.7573   -49.4412                 4394 -16.692088
# 2       Abadia de Goiás  -16.7573   -49.4412                 5384 -16.678533
# 3       Abadia de Goiás  -16.7573   -49.4412                 5501 -16.669792
# 4       Abadia de Goiás  -16.7573   -49.4412                 5512 -15.943810
# 5       Abadia de Goiás  -16.7573   -49.4412                 5638 -16.681860
# 6       Abadia de Goiás  -16.7573   -49.4412                 2251 -17.135991
# 7       Abadia de Goiás  -16.7573   -49.4412                 5923 -15.957963
# 8       Abadia de Goiás  -16.7573   -49.4412               329928 -15.945945
# 9       Abadia de Goiás  -16.7573   -49.4412                 5864 -15.943810
# 10      Abadia de Goiás  -16.7573   -49.4412               446699 -15.945405
# ...

# %% [markdown]
# #### Novo arquivo CSV tratado

# %%
novo_dados.dropna(subset=['lat_corrigido', 'lon_corrigido'],inplace = True)

# %%
novo_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 379084 entries, 0 to 379083
# Data columns (total 45 columns):
# nome                              379084 non-null object
# latitude                          379084 non-null float64
# longitude                         379084 non-null float64
# ID_FAMILIA_CADUNICO               379084 non-null int64
# LAT                               379084 non-null float64
# LOG                               379084 non-null float64
# CODG_FAMILIAR                     379084 non-null int64
# STAT_CADASTRO                     379084 non-null int64
# DESC_STAT_CADASTRO                379084 non-null object
# INDI_CADASTRO_VALIDO              379084 non-null object
# STAT_CONDICAO_CADASTRO            379084 non-null int64
# DESC_CONDICAO_CADASTRO            376551 non-null object
# DATA_CADASTRAM                    379084 non-null object
# DATA_ATUALZ_FAMILIA               379084 non-null object
# ...

# %%
novo_dados = novo_dados.to_csv('dados/novo_dados_primeira_300k_infancia.csv')
novo_dados

# %% [markdown]
# ## Gráficos

# %% [markdown]
# ### Folium

# %%
import folium

# %%
novo_dados.dropna(subset=['lat_corrigido','lon_corrigido'],inplace = True)

# %%
Goias = folium.Map(
    location=[-16.0908158,-48.5083711],
    zoom_start=7
)
for _, loc in novo_dados.iterrows():
    folium.Marker(
        location=[loc['lat_corrigido'], loc['lon_corrigido']],
        
    ).add_to(Goias)

#Goias

# %%
NOME_MUNICIPIO = novo_dados['NOME_MUNICIPIO'] == 'ABADIA DE GOIAS'
ABADIA_DE_GOIAS = novo_dados[NOME_MUNICIPIO]

# %%
ABADIA_DE_GOIAS

# %%
site_lat = ABADIA_DE_GOIAS['lat_corrigido']
site_lon = ABADIA_DE_GOIAS['lon_corrigido']


fig = go.Figure(go.Scattermapbox(
    
        lat=site_lat,
        lon=site_lon,
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=9
        ),
        text = ABADIA_DE_GOIAS['ENDERECO'],
        #text = dados['DESC_CONDICAO_CADASTRO'],
    
    
    ))

fig.update_layout(
    autosize=True,
    hovermode='closest',
    mapbox=go.layout.Mapbox(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=go.layout.mapbox.Center(
            lat=-16,
            lon=-48
        ),
        pitch=0,
        zoom=5
    ),
)

fig.show()

# %%
import plotly.graph_objects as go

import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_us_ag_exports.csv')

for col in df.columns:
    df[col] = df[col].astype(str)

df['text'] = df['state'] + '<br>' + \
    'Beef ' + df['beef'] + ' Dairy ' + df['dairy'] + '<br>' + \
    'Fruits ' + df['total fruits'] + ' Veggies ' + df['total veggies'] + '<br>' + \
    'Wheat ' + df['wheat'] + ' Corn ' + df['corn']

fig = go.Figure(data=go.Choropleth(
    locations=df['code'],
    z=df['total exports'].astype(float),
    locationmode='USA-states',
    colorscale='Reds',
    autocolorscale=False,
    text=df['text'], # hover text
    marker_line_color='white', # line markers between states
    colorbar_title="Millions USD"
))

fig.update_layout(
    title_text='2011 US Agriculture Exports by State<br>(Hover for breakdown)',
    geo = dict(
        scope='usa',
        projection=go.layout.geo.Projection(type = 'albers usa'),
        showlakes=True, # lakes
        lakecolor='rgb(255, 255, 255)'),
)

fig.show()
